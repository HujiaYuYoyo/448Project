# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../ProjectData/msft-orderbook.csv')

# %%
data.head()
# Out:
#               datetime  direct.bid1  direct.ask1  direct.bsize1  \
# 0  2017-04-13 09:30:00        65.29        65.32          53100
# 1  2017-04-13 09:30:01        65.29        65.31           2412
# 2  2017-04-13 09:30:02        65.23        65.25           2123
# 3  2017-04-13 09:30:03        65.18        65.21            276
# 4  2017-04-13 09:30:04        65.16        65.18            272
#
#    direct.asize1  direct.bnum1  direct.anum1  direct.bid2  direct.ask2  \
# 0             17             7             1        65.27        65.35
# 1            505             4             2        65.27        65.32
# 2             80            17             1        65.22        65.26
# 3            100             3             1        65.17        65.22
# 4            100             3             1        65.15        65.19
#
#    direct.bsize2       ...         direct.anum10  direct.last_price  \
# 0              2       ...                     3              65.29
# ...

# %%
plt.plot(range(len(data)), data['direct.wmid'])
plt.show()

# %%
plt.plot(range(len(data)), data['direct.volume'])
plt.show()

# %%
for i in range(1,11):
    plt.plot(range(len(data)), data['direct.bid{}'.format(i)])
plt.show()

# %%
 plt.plot(range(len(data)), data['direct.bid1'])

# %%
plt.show()
